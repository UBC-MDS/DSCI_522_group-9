# %%
import pandas as pd
import numpy as np
import os
import json

from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score, cross_val_predict, cross_validate

from sklearn.dummy import DummyClassifier, DummyRegressor
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression, Ridge
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import make_scorer

# %%
#Import data
data_path = "../data/preprocessed"
train_path = os.path.join(data_path, "train.csv")
test_path = os.path.join(data_path, "test.csv")

#Load data mappings
mappings = json.load(open("data_mapping.json", "r"))

train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)

df = pd.concat([train_df, test_df], axis=0)
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns = mappings['drugs']),
                                     df[mappings['drugs']],
                                     test_size=0.2,
                                     random_state=522)

# %%
#column transformer
preprocessor =  make_column_transformer(
        (StandardScaler(), mappings['numerical']),
        (OrdinalEncoder(categories = [
                                        list(mappings['categories']["Age"].values()), 
                                        list(mappings['categories']["Education"].values()),
                                        list(mappings['categories']["Impulsiveness"].values()),
                                        list(mappings['categories']["SensationSeeking"].values()) 
                                        ]), mappings['ordinal']),
        (OneHotEncoder(drop='if_binary', handle_unknown='ignore'), mappings['categorical']),
        ("drop", mappings['drop'])
    )

# %% [markdown]
# # Custom transformations

# %% [markdown]
# ## Make custom scoring functions

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score
scorers = {
            'f1_score': make_scorer(f1_score, average='micro'),
            'precision_score': make_scorer(precision_score, average='micro'),
            'recall_score': make_scorer(recall_score, average='micro'),
            # 'accuracy_score': make_scorer(accuracy_score)
          }

# %% [markdown]
# ## DummyClassifier

# %%
dummy_cv_results = {}
# Get the mean accuracy for each drug
for drug in mappings['drugs']: 
    dc = DummyClassifier(strategy="stratified")
    # dc.fit(X_train, y_train[drug])
    dummy_cv_results[drug] = pd.DataFrame(
                                cross_validate(dc, 
                                               X_train,
                                               y_train[drug],
                                               return_train_score = True,
                                               scoring=scorers)).mean().round(4)

class_results = pd.DataFrame(dummy_cv_results)
class_results = class_results.drop(index = ["fit_time", "score_time"]).T
class_results = class_results.reset_index()
class_results = class_results.rename(columns = {"index": "target_drug"})
class_results = class_results.set_index("target_drug").T
# Out:
# /home/jenit/yes/envs/573/lib/python3.10/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# /home/jenit/yes/envs/573/lib/python3.10/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(

# %%
class_results
# Out:
# target_drug            Alcohol  Cannabis  Chocolate  Caffeine  Cocaine  \
# test_f1_score           0.2745    0.1777     0.3508    0.5690   0.3647
# train_f1_score          0.2750    0.1577     0.3299    0.5612   0.3412
# test_precision_score    0.2745    0.1777     0.3508    0.5690   0.3647
# train_precision_score   0.2750    0.1577     0.3299    0.5612   0.3412
# test_recall_score       0.2745    0.1777     0.3508    0.5690   0.3647
# train_recall_score      0.2750    0.1577     0.3299    0.5612   0.3412
#
# target_drug            Mushrooms  Nicotine
# test_f1_score             0.3296    0.2069
# train_f1_score            0.3256    0.2041
# test_precision_score      0.3296    0.2069
# train_precision_score     0.3256    0.2041
# test_recall_score         0.3296    0.2069
# train_recall_score        0.3256    0.2041

# %% [markdown]
# ## Creation of SVC pipeline

# %%
svc_pipe =  make_pipeline(
    preprocessor, 
    SVC()
)

param_dist = {
    "svc__class_weight": ["balanced", None],
    "svc__gamma": 10.0 ** np.arange(-4, 4),
    "svc__C": 10.0 ** np.arange(-4, 4)
}

# Save the best model and score for each drug
svc_best_estimator = {}
svc_best_score_by_drug = {}

for drug in mappings['drugs']: 
    random_search = RandomizedSearchCV(svc_pipe, 
                                       param_distributions = param_dist,
                                       n_jobs = -1,
                                       n_iter = 10,
                                       cv = 5, 
                                       return_train_score = True,
                                       scoring=scorers,
                                       refit="f1_score",
                                       random_state = 522
                    )
    random_search.fit(X_train, y_train[drug])
    svc_best_estimator[drug] = random_search.best_estimator_
    svc_best_score_by_drug[drug] = [round(random_search.cv_results_['mean_train_f1_score'].mean(), 4), 
                                    round(random_search.cv_results_['mean_test_f1_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_train_recall_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_test_recall_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_train_precision_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_test_precision_score'].mean(), 4)
                                    ]
    
score_by_drug = pd.DataFrame(svc_best_score_by_drug).T
score_by_drug = score_by_drug.reset_index()
score_by_drug = score_by_drug.rename(columns = {"index": "target_drug",
                                                0: "svc_train_f1_score",
                                                1: 'svc_test_f1_score',
                                                2: 'svc_train_recall_score',
                                                3: 'svc_test_recall_score',
                                                4: 'svc_train_precision_score',
                                                5: 'svc_test_precision_score'
                                }).set_index("target_drug").T
class_results = pd.concat( [class_results,score_by_drug] ,axis=0)
# Out:
# /home/jenit/yes/envs/573/lib/python3.10/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# /home/jenit/yes/envs/573/lib/python3.10/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(

# %% [markdown]
# ## Creation of Logistic Regression pipeline

# %%
lr_pipe =  make_pipeline(
    preprocessor, 
    LogisticRegression(random_state=522, 
                       max_iter=10000,
                       multi_class="multinomial")
)

param_dist = {
    "logisticregression__class_weight": ["balanced", None],
    "logisticregression__C": 10.0 ** np.arange(-4, 4)
}

# Save the best model and score for each drug
lr_best_estimator = {}
lr_best_score_by_drug = {}

for drug in mappings['drugs']: 
    random_search = RandomizedSearchCV(lr_pipe, 
                                       param_distributions = param_dist,
                                       n_jobs = -1,
                                       n_iter = 10,
                                       cv = 5, 
                                       return_train_score = True,
                                       random_state = 522,
                                       scoring=scorers,
                                       refit='f1_score'
                    )
    random_search.fit(X_train, y_train[drug])
    lr_best_estimator[drug] = random_search.best_estimator_
    lr_best_score_by_drug[drug] = [round(random_search.cv_results_['mean_train_f1_score'].mean(), 4), 
                                    round(random_search.cv_results_['mean_test_f1_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_train_recall_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_test_recall_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_train_precision_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_test_precision_score'].mean(), 4)
                                ]
    
lr_score_by_drug = pd.DataFrame(lr_best_score_by_drug).T
lr_score_by_drug = lr_score_by_drug.reset_index()
lr_score_by_drug = lr_score_by_drug.rename(columns = {"index": "target_drug",
                                                0: "lr_train_f1_score",
                                                1: 'lr_test_f1_score',
                                                2: 'lr_train_recall_score',
                                                3: 'lr_test_recall_score',
                                                4: 'lr_train_precision_score',
                                                5: 'lr_test_precision_score'
                                }).set_index("target_drug").T
class_results = pd.concat( [class_results, lr_score_by_drug] ,axis=0)
# Out:
# /home/jenit/yes/envs/573/lib/python3.10/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# /home/jenit/yes/envs/573/lib/python3.10/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(

# %% [markdown]
# ## Creation of KNN pipeline

# %%
knn_pipe =  make_pipeline(
    preprocessor, 
    KNeighborsClassifier(n_jobs=-1)
)

param_dist = {
    "kneighborsclassifier__weights": ["uniform", "distance"],
    "kneighborsclassifier__n_neighbors": [i for i in range(5, 26, 2)]
}

# Save the best model and score for each drug
knn_best_estimator = {}
knn_best_score_by_drug = {}

for drug in mappings['drugs']: 
    random_search = RandomizedSearchCV(knn_pipe, 
                                       param_distributions = param_dist,
                                       n_jobs = -1,
                                       n_iter = 20,
                                       cv = 5, 
                                       return_train_score = True,
                                       random_state = 522,
                                       scoring=scorers,
                                       refit='f1_score'
                    )
    random_search.fit(X_train, y_train[drug])
    knn_best_estimator[drug] = random_search.best_estimator_
    knn_best_score_by_drug[drug] = [round(random_search.cv_results_['mean_train_f1_score'].mean(), 4), 
                                    round(random_search.cv_results_['mean_test_f1_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_train_recall_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_test_recall_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_train_precision_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_test_precision_score'].mean(), 4)
                                ]
    
knn_score_by_drug = pd.DataFrame(knn_best_score_by_drug).T
knn_score_by_drug = knn_score_by_drug.reset_index()
knn_score_by_drug = knn_score_by_drug.rename(columns = {"index": "target_drug",
                                                0: "knn_train_f1_score",
                                                1: 'knn_test_f1_score',
                                                2: 'knn_train_recall_score',
                                                3: 'knn_test_recall_score',
                                                4: 'knn_train_precision_score',
                                                5: 'knn_test_precision_score'
                                }).set_index("target_drug").T

class_results = pd.concat( [class_results, knn_score_by_drug] ,axis=0)
# Out:
# /home/jenit/yes/envs/573/lib/python3.10/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# /home/jenit/yes/envs/573/lib/python3.10/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(

# %% [markdown]
# ## Decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

dt_pipe =  make_pipeline(
    preprocessor, 
    DecisionTreeClassifier(random_state=522,
                           )
)

param_dist = {
    "decisiontreeclassifier__max_depth": [i for i in range(3, 20)],
}

# Save the best model and score for each drug
dt_best_estimator = {}
dt_best_score_by_drug = {}

for drug in mappings['drugs']: 
    random_search = GridSearchCV(dt_pipe, 
                                    #    param_distributions = param_dist,
                                    param_grid=param_dist,
                                       n_jobs = -1,
                                    #    n_iter = 20,
                                       cv = 5, 
                                       return_train_score = True,
                                    #    random_state = 522,
                                       scoring=scorers,
                                       refit='f1_score'
                    )
    random_search.fit(X_train, y_train[drug])
    dt_best_estimator[drug] = random_search.best_estimator_
    dt_best_score_by_drug[drug] = [round(random_search.cv_results_['mean_train_f1_score'].mean(), 4), 
                                    round(random_search.cv_results_['mean_test_f1_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_train_recall_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_test_recall_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_train_precision_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_test_precision_score'].mean(), 4)
                                ]
    
dt_score_by_drug = pd.DataFrame(dt_best_score_by_drug).T
dt_score_by_drug = dt_score_by_drug.reset_index()
dt_score_by_drug = dt_score_by_drug.rename(columns = {"index": "target_drug",
                                                0: "dt_train_f1_score",
                                                1: 'dt_test_f1_score',
                                                2: 'dt_train_recall_score',
                                                3: 'dt_test_recall_score',
                                                4: 'dt_train_precision_score',
                                                5: 'dt_test_precision_score'
                                }).set_index("target_drug").T

class_results = pd.concat( [class_results, dt_score_by_drug] ,axis=0)
# Out:
# /home/jenit/yes/envs/573/lib/python3.10/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# /home/jenit/yes/envs/573/lib/python3.10/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(

# %% [markdown]
# ## NN classifier

# %%
from sklearn.neural_network import MLPClassifier

#Creation of NN pipeline
nn_pipe =  make_pipeline(
    preprocessor, 
    MLPClassifier((32,32,16),
                 learning_rate="invscaling",
                 random_state=522,
                 max_iter=5000,
                 batch_size=8,
                 learning_rate_init=0.00001,
                 early_stopping=True
                 )
)

# Save the best model and score for each drug
nn_best_estimator = {}
nn_best_score_by_drug = {}

for drug in mappings['drugs']:
    print(f"Drug: {drug}")
    nn_pipe.fit(X_train, y_train[drug])
    
    nn_best_estimator[drug] = nn_pipe
    nn_best_score_by_drug[drug] = [round(f1_score(y_train[drug], nn_pipe.predict(X_train), average='micro'), 4), 
                                    round(f1_score(y_test[drug], nn_pipe.predict(X_test), average='micro'), 4),
                                    round(recall_score(y_train[drug], nn_pipe.predict(X_train), average='micro'), 4),
                                    round(recall_score(y_test[drug], nn_pipe.predict(X_test), average='micro'), 4),
                                    round(precision_score(y_train[drug], nn_pipe.predict(X_train), average='micro'), 4),
                                    round(precision_score(y_test[drug], nn_pipe.predict(X_test), average='micro'), 4)
                                ]
    
score_by_nn = pd.DataFrame(nn_best_score_by_drug).T
score_by_nn = score_by_nn.reset_index()
score_by_nn = score_by_nn.rename(columns ={"index": "target_drug",
                                                0: "nn_train_f1_score",
                                                1: 'nn_test_f1_score',
                                                2: 'nn_train_recall_score',
                                                3: 'nn_test_recall_score',
                                                4: 'nn_train_precision_score',
                                                5: 'nn_test_precision_score'
                                   }).set_index("target_drug").T

class_results = pd.concat( [class_results, score_by_nn] ,axis=0)
# Out:
# Drug: Alcohol
# Drug: Cannabis
# Drug: Chocolate
# Drug: Caffeine
# Drug: Cocaine
# Drug: Mushrooms
# Drug: Nicotine

# %%
from sklearn.metrics import confusion_matrix  # Recommended method in sklearn 1.0

cm = pd.DataFrame(confusion_matrix(
    y_test['Alcohol'], dt_best_estimator['Alcohol'].predict(X_test), labels=[f"CL{i}" for i in range(0,7)]
))
cm.style.background_gradient(cmap='PuBu', low=0, high=1)
# Out:
# <style type="text/css">
# #T_b44f9_row0_col0, #T_b44f9_row0_col1, #T_b44f9_row0_col2, #T_b44f9_row0_col3, #T_b44f9_row0_col4, #T_b44f9_row0_col5, #T_b44f9_row0_col6, #T_b44f9_row1_col0, #T_b44f9_row1_col1, #T_b44f9_row1_col2, #T_b44f9_row1_col3, #T_b44f9_row1_col4, #T_b44f9_row1_col5, #T_b44f9_row1_col6, #T_b44f9_row2_col0, #T_b44f9_row2_col1, #T_b44f9_row2_col2, #T_b44f9_row2_col3, #T_b44f9_row2_col4, #T_b44f9_row2_col6, #T_b44f9_row3_col0, #T_b44f9_row3_col1, #T_b44f9_row3_col2, #T_b44f9_row3_col3, #T_b44f9_row3_col4, #T_b44f9_row3_col6, #T_b44f9_row4_col0, #T_b44f9_row4_col1, #T_b44f9_row4_col2, #T_b44f9_row4_col3, #T_b44f9_row4_col6, #T_b44f9_row5_col0, #T_b44f9_row5_col1, #T_b44f9_row5_col2, #T_b44f9_row5_col3, #T_b44f9_row5_col4, #T_b44f9_row6_col0, #T_b44f9_row6_col1, #T_b44f9_row6_col2, #T_b44f9_row6_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b44f9_row2_col5 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_b44f9_row3_col5 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_b44f9_row4_col4 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_b44f9_row4_col5 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_b44f9_row5_col5, #T_b44f9_row5_col6, #T_b44f9_row6_col4 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_b44f9_row6_col5 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_b44f9_row6_col6 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# </style>
# <table id="T_b44f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b44f9_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_b44f9_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_b44f9_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_b44f9_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_b44f9_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_b44f9_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_b44f9_level0_col6" class="col_heading level0 col6" >6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b44f9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b44f9_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_b44f9_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_b44f9_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_b44f9_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b44f9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b44f9_row0_col5" class="data row0 col5" >8</td>
#       <td id="T_b44f9_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b44f9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b44f9_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_b44f9_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_b44f9_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_b44f9_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_b44f9_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_b44f9_row1_col5" class="data row1 col5" >8</td>
#       <td id="T_b44f9_row1_col6" class="data row1 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b44f9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b44f9_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_b44f9_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_b44f9_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_b44f9_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_b44f9_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_b44f9_row2_col5" class="data row2 col5" >14</td>
#       <td id="T_b44f9_row2_col6" class="data row2 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b44f9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b44f9_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_b44f9_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_b44f9_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_b44f9_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_b44f9_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_b44f9_row3_col5" class="data row3 col5" >34</td>
#       <td id="T_b44f9_row3_col6" class="data row3 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b44f9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b44f9_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_b44f9_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_b44f9_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_b44f9_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_b44f9_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_b44f9_row4_col5" class="data row4 col5" >51</td>
#       <td id="T_b44f9_row4_col6" class="data row4 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b44f9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b44f9_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_b44f9_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_b44f9_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_b44f9_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_b44f9_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_b44f9_row5_col5" class="data row5 col5" >149</td>
#       <td id="T_b44f9_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b44f9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b44f9_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_b44f9_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_b44f9_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_b44f9_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_b44f9_row6_col4" class="data row6 col4" >5</td>
#       <td id="T_b44f9_row6_col5" class="data row6 col5" >104</td>
#       <td id="T_b44f9_row6_col6" class="data row6 col6" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
class_results.reset_index().style.background_gradient(cmap='PuBu', low=0, high=1)
# Out:
# <style type="text/css">
# #T_c4f48_row0_col1, #T_c4f48_row0_col7, #T_c4f48_row1_col1, #T_c4f48_row1_col2, #T_c4f48_row1_col5, #T_c4f48_row1_col6, #T_c4f48_row1_col7, #T_c4f48_row2_col1, #T_c4f48_row2_col7, #T_c4f48_row3_col1, #T_c4f48_row3_col2, #T_c4f48_row3_col5, #T_c4f48_row3_col6, #T_c4f48_row3_col7, #T_c4f48_row4_col1, #T_c4f48_row4_col7, #T_c4f48_row5_col1, #T_c4f48_row5_col2, #T_c4f48_row5_col5, #T_c4f48_row5_col6, #T_c4f48_row5_col7, #T_c4f48_row7_col3, #T_c4f48_row7_col4, #T_c4f48_row9_col3, #T_c4f48_row9_col4, #T_c4f48_row11_col3, #T_c4f48_row11_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c4f48_row0_col2, #T_c4f48_row2_col2, #T_c4f48_row4_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_c4f48_row0_col3, #T_c4f48_row2_col3, #T_c4f48_row4_col3 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_c4f48_row0_col4, #T_c4f48_row2_col4, #T_c4f48_row4_col4, #T_c4f48_row19_col3, #T_c4f48_row21_col3, #T_c4f48_row23_col3, #T_c4f48_row25_col5, #T_c4f48_row27_col5, #T_c4f48_row29_col5 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_c4f48_row0_col5, #T_c4f48_row2_col5, #T_c4f48_row4_col5, #T_c4f48_row13_col4, #T_c4f48_row15_col4, #T_c4f48_row17_col4 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_c4f48_row0_col6, #T_c4f48_row2_col6, #T_c4f48_row4_col6 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_c4f48_row1_col3, #T_c4f48_row3_col3, #T_c4f48_row5_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_c4f48_row1_col4, #T_c4f48_row3_col4, #T_c4f48_row5_col4, #T_c4f48_row13_col5, #T_c4f48_row15_col5, #T_c4f48_row17_col5 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_c4f48_row6_col1, #T_c4f48_row8_col1, #T_c4f48_row10_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_c4f48_row6_col2, #T_c4f48_row8_col2, #T_c4f48_row10_col2 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_c4f48_row6_col3, #T_c4f48_row8_col3, #T_c4f48_row10_col3, #T_c4f48_row30_col5, #T_c4f48_row31_col6, #T_c4f48_row32_col5, #T_c4f48_row33_col6, #T_c4f48_row34_col5, #T_c4f48_row35_col6 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_c4f48_row6_col4, #T_c4f48_row8_col4, #T_c4f48_row10_col4, #T_c4f48_row12_col5, #T_c4f48_row13_col7, #T_c4f48_row14_col5, #T_c4f48_row15_col7, #T_c4f48_row16_col5, #T_c4f48_row17_col7 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_c4f48_row6_col5, #T_c4f48_row8_col5, #T_c4f48_row10_col5 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_c4f48_row6_col6, #T_c4f48_row8_col6, #T_c4f48_row10_col6 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_c4f48_row6_col7, #T_c4f48_row8_col7, #T_c4f48_row10_col7 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_c4f48_row7_col1, #T_c4f48_row9_col1, #T_c4f48_row11_col1, #T_c4f48_row12_col4, #T_c4f48_row14_col4, #T_c4f48_row16_col4 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_c4f48_row7_col2, #T_c4f48_row9_col2, #T_c4f48_row11_col2, #T_c4f48_row31_col2, #T_c4f48_row33_col2, #T_c4f48_row35_col2 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_c4f48_row7_col5, #T_c4f48_row9_col5, #T_c4f48_row11_col5, #T_c4f48_row25_col3, #T_c4f48_row27_col3, #T_c4f48_row29_col3 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_c4f48_row7_col6, #T_c4f48_row9_col6, #T_c4f48_row11_col6, #T_c4f48_row25_col7, #T_c4f48_row27_col7, #T_c4f48_row29_col7 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_c4f48_row7_col7, #T_c4f48_row9_col7, #T_c4f48_row11_col7 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_c4f48_row12_col1, #T_c4f48_row14_col1, #T_c4f48_row16_col1 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_c4f48_row12_col2, #T_c4f48_row14_col2, #T_c4f48_row16_col2 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_c4f48_row12_col3, #T_c4f48_row14_col3, #T_c4f48_row16_col3 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_c4f48_row12_col6, #T_c4f48_row14_col6, #T_c4f48_row16_col6 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_c4f48_row12_col7, #T_c4f48_row13_col6, #T_c4f48_row14_col7, #T_c4f48_row15_col6, #T_c4f48_row16_col7, #T_c4f48_row17_col6, #T_c4f48_row31_col1, #T_c4f48_row33_col1, #T_c4f48_row35_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_c4f48_row13_col1, #T_c4f48_row15_col1, #T_c4f48_row17_col1, #T_c4f48_row25_col1, #T_c4f48_row27_col1, #T_c4f48_row29_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_c4f48_row13_col2, #T_c4f48_row15_col2, #T_c4f48_row17_col2 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_c4f48_row13_col3, #T_c4f48_row15_col3, #T_c4f48_row17_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_c4f48_row18_col1, #T_c4f48_row20_col1, #T_c4f48_row22_col1, #T_c4f48_row24_col2, #T_c4f48_row24_col5, #T_c4f48_row26_col2, #T_c4f48_row26_col5, #T_c4f48_row28_col2, #T_c4f48_row28_col5 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_c4f48_row18_col2, #T_c4f48_row20_col2, #T_c4f48_row22_col2, #T_c4f48_row24_col4, #T_c4f48_row26_col4, #T_c4f48_row28_col4 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_c4f48_row18_col3, #T_c4f48_row20_col3, #T_c4f48_row22_col3 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_c4f48_row18_col4, #T_c4f48_row20_col4, #T_c4f48_row22_col4, #T_c4f48_row24_col3, #T_c4f48_row24_col6, #T_c4f48_row24_col7, #T_c4f48_row26_col3, #T_c4f48_row26_col6, #T_c4f48_row26_col7, #T_c4f48_row28_col3, #T_c4f48_row28_col6, #T_c4f48_row28_col7 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_c4f48_row18_col5, #T_c4f48_row20_col5, #T_c4f48_row22_col5 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_c4f48_row18_col6, #T_c4f48_row20_col6, #T_c4f48_row22_col6 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_c4f48_row18_col7, #T_c4f48_row20_col7, #T_c4f48_row22_col7 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_c4f48_row19_col1, #T_c4f48_row21_col1, #T_c4f48_row23_col1, #T_c4f48_row30_col7, #T_c4f48_row32_col7, #T_c4f48_row34_col7 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_c4f48_row19_col2, #T_c4f48_row21_col2, #T_c4f48_row23_col2 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_c4f48_row19_col4, #T_c4f48_row21_col4, #T_c4f48_row23_col4 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_c4f48_row19_col5, #T_c4f48_row21_col5, #T_c4f48_row23_col5 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_c4f48_row19_col6, #T_c4f48_row21_col6, #T_c4f48_row23_col6, #T_c4f48_row30_col6, #T_c4f48_row32_col6, #T_c4f48_row34_col6 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_c4f48_row19_col7, #T_c4f48_row21_col7, #T_c4f48_row23_col7 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_c4f48_row24_col1, #T_c4f48_row26_col1, #T_c4f48_row28_col1 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_c4f48_row25_col2, #T_c4f48_row27_col2, #T_c4f48_row29_col2, #T_c4f48_row30_col1, #T_c4f48_row32_col1, #T_c4f48_row34_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_c4f48_row25_col4, #T_c4f48_row27_col4, #T_c4f48_row29_col4 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_c4f48_row25_col6, #T_c4f48_row27_col6, #T_c4f48_row29_col6, #T_c4f48_row31_col3, #T_c4f48_row33_col3, #T_c4f48_row35_col3 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_c4f48_row30_col2, #T_c4f48_row31_col7, #T_c4f48_row32_col2, #T_c4f48_row33_col7, #T_c4f48_row34_col2, #T_c4f48_row35_col7 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_c4f48_row30_col3, #T_c4f48_row32_col3, #T_c4f48_row34_col3 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_c4f48_row30_col4, #T_c4f48_row32_col4, #T_c4f48_row34_col4 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_c4f48_row31_col4, #T_c4f48_row33_col4, #T_c4f48_row35_col4 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_c4f48_row31_col5, #T_c4f48_row33_col5, #T_c4f48_row35_col5 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# </style>
# <table id="T_c4f48">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target_drug</th>
#       <th id="T_c4f48_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_c4f48_level0_col1" class="col_heading level0 col1" >Alco

# %% [markdown]
# # Treating it as a regression problem

# %%
ranges = [i/7 for i in range(1,8)]
y_train_reg = y_train.replace({f"CL{i}": ranges[i] for i in range(7)})
y_test_reg = y_test.replace({f"CL{i}": ranges[i] for i in range(7)})

# %%
from sklearn.metrics import mean_squared_error
def get_class(num):
    intervals = [i/7 for i in range(1,8)]
    if num <= intervals[0]:
        return "CL0"
    elif num <= intervals[1]:
        return "CL1"
    elif num <= intervals[2]:
        return "CL2"
    elif num <= intervals[3]:
        return "CL3"
    elif num <= intervals[4]:
        return "CL4"
    elif num <= intervals[5]:
        return "CL5"
    else:
        return "CL6"
    
def get_regression_accuracy(estimator):
    #Tries to get a classification accuracy based on the quantitative metric predicted
    accuracy = {}
    error = make_scorer(mean_squared_error, greater_is_better=False)
    for drug in mappings['drugs']:
        preds = np.array(list(map(get_class, estimator[drug].predict(X_train))))
        res = (y_train[drug] == preds).value_counts()
        accuracy[drug] = res[True]/res.sum()
    return pd.DataFrame({"target_drug": list(accuracy.keys()),
                         "accuracy": list(accuracy.values()),
                         "train_error": [error(estimator[drug], X_train, y_train_reg[drug]) 
                                         for drug in mappings['drugs']],
                         "test_error": [error(estimator[drug], X_test, y_test_reg[drug]) 
                                         for drug in mappings['drugs']]
                        }), preds

# %% [markdown]
# ## Dummy regressor

# %%
dummy_r_results = {}
dr_estimator = {}

# Get the mean accuracy for each drug
for drug in mappings['drugs']:
    dr = DummyRegressor(strategy='median')
    dr.fit(X_train, y_train_reg[drug])
    # dummy_r_results[drug] = dr.predict(X_train)
    dr_estimator[drug] = dr
    
output = get_regression_accuracy(dr_estimator)
reg_scores =  pd.DataFrame({"target_drug": mappings['drugs'],
                            # "dummy_accuracy": output[0]['accuracy'],
                            "dummy_train_error":abs( output[0]['train_error']),
                            "dummy_test_error": abs(output[0]['test_error'])}).set_index('target_drug').T
reg_scores
# Out:
# target_drug         Alcohol  Cannabis  Chocolate  Caffeine   Cocaine  \
# dummy_train_error  0.038407  0.106412   0.024035  0.032453  0.074690
# dummy_test_error   0.040708  0.107995   0.026038  0.024089  0.072322
#
# target_drug        Mushrooms  Nicotine
# dummy_train_error   0.072768  0.120284
# dummy_test_error    0.072051  0.117252

# %% [markdown]
# ## Creation of Ridge Regression pipeline

# %%
ridge_pipe =  make_pipeline(
    preprocessor, 
    Ridge(max_iter=1000)
)

param_dist = {"ridge__alpha": 10.0 ** np.arange(-5, 5, 1)}

# Save the best model and score for each drug
ridge_best_estimator = {}
ridge_best_score_by_drug = {}

for drug in mappings['drugs']: 
    random_search = RandomizedSearchCV(ridge_pipe, 
                                       param_distributions = param_dist,
                                       n_jobs = -1,
                                       n_iter = 10,
                                       cv = 5, 
                                       return_train_score = True,
                                       random_state = 522
                    )
    random_search.fit(X_train, y_train_reg[drug])
    ridge_best_estimator[drug] = random_search.best_estimator_
    
output = get_regression_accuracy(ridge_best_estimator)
ridge_results = pd.DataFrame({"target_drug": mappings['drugs'],
                            # "ridge_accuracy": output[0]['accuracy'],
                            "ridge_train_error": abs(output[0]['train_error']),
                            "ridge_test_error": abs(output[0]['test_error'])}).set_index("target_drug").T
reg_scores = pd.concat( [reg_scores, ridge_results] ,axis=0)

# %% [markdown]
# ## NN regressor

# %%
from sklearn.neural_network import MLPRegressor
#Creation of NN pipeline
nn_pipe =  make_pipeline(
    preprocessor, 
    MLPRegressor((32,32,16),
                 learning_rate="invscaling",
                 random_state=522,
                 max_iter=5000,
                 batch_size=16,
                 learning_rate_init=0.0001)
)

# Save the best model and score for each drug
nn_best_estimator = {}
nn_best_score_by_drug = {}

for drug in mappings['drugs']: 
    nn_pipe.fit(X_train, y_train_reg[drug])
    nn_best_score_by_drug[drug] = [
                                ]
    nn_best_estimator[drug] = nn_pipe
    
output = get_regression_accuracy(nn_best_estimator)
nn_results = pd.DataFrame({"target_drug": mappings['drugs'],
                            # "ridge_accuracy": output[0]['accuracy'],
                            "nn_train_error": abs(output[0]['train_error']),
                            "nn_test_error": abs(output[0]['test_error'])}).set_index("target_drug").T
reg_scores = pd.concat( [reg_scores, nn_results] ,axis=0)

# %%
x_enc = preprocessor.fit_transform(X_train)
pd.DataFrame(x_enc, columns=preprocessor.get_feature_names_out()).corr().style.background_gradient(cmap = "PuOr")
# Out:
# <style type="text/css">
# #T_55490_row0_col0, #T_55490_row1_col1, #T_55490_row2_col2, #T_55490_row3_col3, #T_55490_row4_col4, #T_55490_row5_col5, #T_55490_row6_col6, #T_55490_row7_col7, #T_55490_row8_col8, #T_55490_row9_col9 {
#   background-color: #2d004b;
#   color: #f1f1f1;
# }
# #T_55490_row0_col1, #T_55490_row0_col3, #T_55490_row0_col4, #T_55490_row1_col0, #T_55490_row3_col9, #T_55490_row4_col7, #T_55490_row5_col2, #T_55490_row5_col8, #T_55490_row8_col5, #T_55490_row9_col6 {
#   background-color: #7f3b08;
#   color: #f1f1f1;
# }
# #T_55490_row0_col2 {
#   background-color: #d57811;
#   color: #f1f1f1;
# }
# #T_55490_row0_col5 {
#   background-color: #c76b0c;
#   color: #f1f1f1;
# }
# #T_55490_row0_col6, #T_55490_row5_col9 {
#   background-color: #b65a07;
#   color: #f1f1f1;
# }
# #T_55490_row0_col7 {
#   background-color: #fedbac;
#   color: #000000;
# }
# #T_55490_row0_col8 {
#   background-color: #fdbd6e;
#   color: #000000;
# }
# #T_55490_row0_col9, #T_55490_row7_col5 {
#   background-color: #b75c07;
#   color: #f1f1f1;
# }
# #T_55490_row1_col2, #T_55490_row3_col1 {
#   background-color: #fedeb3;
#   color: #000000;
# }
# #T_55490_row1_col3 {
#   background-color: #fdba68;
#   color: #000000;
# }
# #T_55490_row1_col4 {
#   background-color: #f6f6f7;
#   color: #000000;
# }
# #T_55490_row1_col5 {
#   background-color: #ea9530;
#   color: #f1f1f1;
# }
# #T_55490_row1_col6, #T_55490_row6_col0, #T_55490_row6_col3 {
#   background-color: #ee9b39;
#   color: #000000;
# }
# #T_55490_row1_col7 {
#   background-color: #fecd8f;
#   color: #000000;
# }
# #T_55490_row1_col8, #T_55490_row6_col4 {
#   background-color: #fce5c5;
#   color: #000000;
# }
# #T_55490_row1_col9 {
#   background-color: #c6690c;
#   color: #f1f1f1;
# }
# #T_55490_row2_col0 {
#   background-color: #fbb55e;
#   color: #000000;
# }
# #T_55490_row2_col1 {
#   background-color: #f8f3ec;
#   color: #000000;
# }
# #T_55490_row2_col3 {
#   background-color: #e3881d;
#   color: #f1f1f1;
# }
# #T_55490_row2_col4, #T_55490_row2_col6, #T_55490_row5_col3 {
#   background-color: #ed9936;
#   color: #000000;
# }
# #T_55490_row2_col5, #T_55490_row3_col7 {
#   background-color: #b05606;
#   color: #f1f1f1;
# }
# #T_55490_row2_col7 {
#   background-color: #faeedc;
#   color: #000000;
# }
# #T_55490_row2_col8 {
#   background-color: #e2e3ef;
#   color: #000000;
# }
# #T_55490_row2_col9 {
#   background-color: #f4a84c;
#   color: #000000;
# }
# #T_55490_row3_col0, #T_55490_row4_col2 {
#   background-color: #c2660b;
#   color: #f1f1f1;
# }
# #T_55490_row3_col2 {
#   background-color: #e18417;
#   color: #f1f1f1;
# }
# #T_55490_row3_col4 {
#   background-color: #faeedf;
#   color: #000000;
# }
# #T_55490_row3_col5 {
#   background-color: #fdbc6b;
#   color: #000000;
# }
# #T_55490_row3_col6 {
#   background-color: #e78f27;
#   color: #f1f1f1;
# }
# #T_55490_row3_col8 {
#   background-color: #b25706;
#   color: #f1f1f1;
# }
# #T_55490_row4_col0, #T_55490_row8_col3 {
#   background-color: #874008;
#   color: #f1f1f1;
# }
# #T_55490_row4_col1 {
#   background-color: #f3f3f5;
#   color: #000000;
# }
# #T_55490_row4_col3 {
#   background-color: #feddaf;
#   color: #000000;
# }
# #T_55490_row4_col5, #T_55490_row7_col1, #T_55490_row8_col9, #T_55490_row9_col7 {
#   background-color: #fedaa9;
#   color: #000000;
# }
# #T_55490_row4_col6, #T_55490_row6_col5 {
#   background-color: #fdc278;
#   color: #000000;
# }
# #T_55490_row4_col8 {
#   background-color: #aa5306;
#   color: #f1f1f1;
# }
# #T_55490_row4_col9 {
#   background-color: #914507;
#   color: #f1f1f1;
# }
# #T_55490_row5_col0 {
#   background-color: #dc7f13;
#   color: #f1f1f1;
# }
# #T_55490_row5_col1 {
#   background-color: #f6aa4f;
#   color: #000000;
# }
# #T_55490_row5_col4 {
#   background-color: #fde2bb;
#   color: #000000;
# }
# #T_55490_row5_col6 {
#   background-color: #eb9733;
#   color: #f1f1f1;
# }
# #T_55490_row5_col7, #T_55490_row8_col4 {
#   background-color: #b95e08;
#   color: #f1f1f1;
# }
# #T_55490_row6_col1 {
#   background-color: #fed39c;
#   color: #000000;
# }
# #T_55490_row6_col2, #T_55490_row9_col1 {
#   background-color: #f1a242;
#   color: #000000;
# }
# #T_55490_row6_col7 {
#   background-color: #d47610;
#   color: #f1f1f1;
# }
# #T_55490_row6_col8 {
#   background-color: #d77a11;
#   color: #f1f1f1;
# }
# #T_55490_row6_col9 {
#   background-color: #8b4208;
#   color: #f1f1f1;
# }
# #T_55490_row7_col0 {
#   background-color: #fde5c3;
#   color: #000000;
# }
# #T_55490_row7_col2 {
#   background-color: #fee0b6;
#   color: #000000;
# }
# #T_55490_row7_col3, #T_55490_row9_col3 {
#   background-color: #813c08;
#   color: #f1f1f1;
# }
# #T_55490_row7_col4 {
#   background-color: #8d4307;
#   color: #f1f1f1;
# }
# #T_55490_row7_col6 {
#   background-color: #a04d07;
#   color: #f1f1f1;
# }
# #T_55490_row7_col8, #T_55490_row8_col7 {
#   background-color: #a59dc8;
#   color: #f1f1f1;
# }
# #T_55490_row7_col9 {
#   background-color: #fdc175;
#   color: #000000;
# }
# #T_55490_row8_col0 {
#   background-color: #fdcc8c;
#   color: #000000;
# }
# #T_55490_row8_col1 {
#   background-color: #faecd7;
#   color: #000000;
# }
# #T_55490_row8_col2 {
#   background-color: #f0f1f4;
#   color: #000000;
# }
# #T_55490_row8_col6 {
#   background-color: #a85206;
#   color: #f1f1f1;
# }
# #T_55490_row9_col0 {
#   background-color: #e9932d;
#   color: #f1f1f1;
# }
# #T_55490_row9_col2 {
#   background-color: #f3a649;
#   color: #000000;
# }
# #T_55490_row9_col4 {
#   background-color: #cb6e0d;
#   color: #f1f1f1;
# }
# #T_55490_row9_col5 {
#   background-color: #d97b12;
#   color: #f1f1f1;
# }
# #T_55490_row9_col8 {
#   background-color: #fbe9cf;
#   color: #000000;
# }
# </style>
# <table id="T_55490">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55490_level0_col0" class="col_heading level0 col0" >standardscaler__Neuroticism</th>
#       <th id="T_55490_level0_col1" class="col_heading level0 col1" >standardscaler__Extraversion</th>
#       <th id="T_55490_level0_col2" class="col_heading level0 col2" >standardscaler__Openness</th>
#       <th id="T_55490_level0_col3" class="col_heading level0 col3" >standardscaler__Agreeableness</th>
#       <th id="T_55490_level0_col4" class="col_heading level0 col4" >standardscaler__Conscientiousness</th>
#       <th id="T_55490_level0_col5" class="col_heading level0 col5" >ordinalencoder__Age</th>
#       <th id="T_55490_level0_col6" class="col_heading level0 col6" >ordinalencoder__Education</th>
#       <th id="T_55490_level0_col7" class="col_heading level0 col7" >ordinalencoder__Impulsiveness</th>
#       <th id="T_55490_level0_col8" class="col_heading level0 col8" >ordinalencoder__SensationSeeking</th>
#       <th id="T_55490_level0_col9" class="col_heading level0 col9" >onehotencoder__Gender_Male</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55490_level0_row0" class="row_heading level0 row0" >standardscaler__Neuroticism</th>
#       <td id="T_55490_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_55490_row0_col1" class="data row0 col1" >-0.419846</td>
#       <td id="T_55490_row0_col2" class="data row0 col2" >-0.002448</td>
#       <td id="T_55490_row0_col3" class="data row0 col3" >-0.230351</td>
#       <td id="T_55490_row0_col4" class="data row0 col4" >-0.393290</td>
#       <td id="T_55490_row0_col5" class="data row0 col5" >-0.145798</td>
#       <td id="T_55490_row0_col6" class="data row0 col6" >-0.067213</td>
#       <td id="T_55490_row0_col7" class="data row0 col7" >0.174470</td>
#       <td id="T_55490_row0_col8" class="data row0 col8" >0.078918</td>
#       <td id="T_55490_row0_col9" class="data row0 col9" >-0.090144</td>
#     </tr>
#     <tr>
#       <th id="T_55490_level0_row1" class="row_heading level0 row1" >standardscaler__Extraversion</th>
#       <td id="T_55490_row1_col0" class="data row1 col0" >-0.419846</td>
#       <td id="T_55490_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_55490_row1_col2" class="data row1 col2" >0.265184</td>
#       <td id="T_55490_row1_col3" class="data row1 col3" >0.145320</td>
#       <td id="T_55490_row1_col4" class="data row1 col4" >0.307213</td>
#       <td id="T_55490_row1_col5" class="data row1 col5" >-0.028150</td>
#       <td id="T_55490_row1_col6" class="data row1 col6" >0.104393</td>
#       <td id="T_55490_row1_col7" class="data row1 col7" >0.127137</td>
#       <td id="T_55490_row1_col8" class="data row1 col8" >0.223371</td>
#       <td id="T_55490_row1_col9" class="data row1 col9" >-0.051465</td>
#     </tr>
#     <tr>
#       <th

# %% [markdown]
# ## Support Vector Regression

# %%
from sklearn.svm import SVR

svr_pipe =  make_pipeline(
    preprocessor, 
    SVR()
)

param_dist = {
    "svr__gamma": 10.0 ** np.arange(-4, 4),
    "svr__C": 10.0 ** np.arange(-4, 4)
}

# Save the best model and score for each drug
svr_best_estimator = {}
svr_best_score_by_drug = {}

for drug in mappings['drugs']: 
    random_search = RandomizedSearchCV(svr_pipe, 
                                       param_distributions = param_dist,
                                       n_jobs = -1,
                                       n_iter = 10,
                                       cv = 5, 
                                       return_train_score = True,
                                       random_state = 522
                    )
    random_search.fit(X_train, y_train_reg[drug])
    svr_best_estimator[drug] = random_search.best_estimator_
    
output = get_regression_accuracy(svr_best_estimator)
svr_results = pd.DataFrame({"target_drug": mappings['drugs'],
                            # "ridge_accuracy": output[0]['accuracy'],
                            "svr_train_error": abs(output[0]['train_error']),
                            "svr_test_error": abs(output[0]['test_error'])}).set_index("target_drug").T
reg_scores = pd.concat( [reg_scores, svr_results] ,axis=0)

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dr_pipe =  make_pipeline(
    preprocessor, 
    DecisionTreeRegressor(random_state=522)
)

param_dist = {
    "decisiontreeregressor__max_depth": [i for i in range(3, 20)],
}

# Save the best model and score for each drug
dr_best_estimator = {}
dr_best_score_by_drug = {}

for drug in mappings['drugs']: 
    random_search = GridSearchCV(dr_pipe, 
                                    #    param_distributions = param_dist,
                                    param_grid=param_dist,
                                       n_jobs = -1,
                                    #    n_iter = 20,
                                       cv = 5, 
                                       return_train_score = True
                    )
    random_search.fit(X_train, y_train_reg[drug])
    dr_best_estimator[drug] = random_search.best_estimator_
    
output = get_regression_accuracy(dr_best_estimator)
dr_results = pd.DataFrame({"target_drug": mappings['drugs'],
                            # "ridge_accuracy": output[0]['accuracy'],
                            "dr_train_error": abs(output[0]['train_error']),
                            "dr_test_error": abs(output[0]['test_error'])}).set_index("target_drug").T
reg_scores = pd.concat( [reg_scores, dr_results] ,axis=0)

# %%
reg_scores.style.background_gradient(cmap='BuPu_r', low=1,high=0)
# Out:
# <style type="text/css">
# #T_b32ac_row0_col0, #T_b32ac_row6_col3, #T_b32ac_row9_col0 {
#   background-color: #909eca;
#   color: #f1f1f1;
# }
# #T_b32ac_row0_col1 {
#   background-color: #f4fafc;
#   color: #000000;
# }
# #T_b32ac_row0_col2, #T_b32ac_row2_col2, #T_b32ac_row2_col4, #T_b32ac_row2_col5, #T_b32ac_row3_col1, #T_b32ac_row6_col0, #T_b32ac_row6_col2, #T_b32ac_row6_col4, #T_b32ac_row8_col4, #T_b32ac_row9_col4 {
#   background-color: #8d98c7;
#   color: #f1f1f1;
# }
# #T_b32ac_row0_col3, #T_b32ac_row1_col0 {
#   background-color: #92a3cd;
#   color: #f1f1f1;
# }
# #T_b32ac_row0_col4 {
#   background-color: #a8c3de;
#   color: #000000;
# }
# #T_b32ac_row0_col5, #T_b32ac_row6_col6 {
#   background-color: #afc8e0;
#   color: #000000;
# }
# #T_b32ac_row0_col6, #T_b32ac_row1_col1, #T_b32ac_row4_col4, #T_b32ac_row4_col5, #T_b32ac_row5_col0, #T_b32ac_row5_col2, #T_b32ac_row5_col3, #T_b32ac_row5_col4 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_b32ac_row1_col2, #T_b32ac_row1_col3, #T_b32ac_row3_col2, #T_b32ac_row9_col2, #T_b32ac_row9_col5 {
#   background-color: #8e9ac8;
#   color: #f1f1f1;
# }
# #T_b32ac_row1_col4 {
#   background-color: #a6c2dd;
#   color: #000000;
# }
# #T_b32ac_row1_col5 {
#   background-color: #aec7e0;
#   color: #000000;
# }
# #T_b32ac_row1_col6 {
#   background-color: #f1f7fa;
#   color: #000000;
# }
# #T_b32ac_row2_col0, #T_b32ac_row3_col3, #T_b32ac_row3_col4, #T_b32ac_row3_col5, #T_b32ac_row4_col6, #T_b32ac_row6_col5, #T_b32ac_row7_col1, #T_b32ac_row7_col3, #T_b32ac_row7_col4, #T_b32ac_row7_col5, #T_b32ac_row8_col0, #T_b32ac_row8_col2, #T_b32ac_row8_col5, #T_b32ac_row9_col3 {
#   background-color: #8c97c6;
#   color: #f1f1f1;
# }
# #T_b32ac_row2_col1, #T_b32ac_row7_col2 {
#   background-color: #8f9bc9;
#   color: #f1f1f1;
# }
# #T_b32ac_row2_col3, #T_b32ac_row3_col0, #T_b32ac_row7_col0, #T_b32ac_row8_col3 {
#   background-color: #8f9dc9;
#   color: #f1f1f1;
# }
# #T_b32ac_row2_col6 {
#   background-color: #b9cee4;
#   color: #000000;
# }
# #T_b32ac_row3_col6 {
#   background-color: #b1c9e1;
#   color: #000000;
# }
# #T_b32ac_row4_col0 {
#   background-color: #e4eff6;
#   color: #000000;
# }
# #T_b32ac_row4_col1 {
#   background-color: #a4c0dc;
#   color: #000000;
# }
# #T_b32ac_row4_col2 {
#   background-color: #eff6fa;
#   color: #000000;
# }
# #T_b32ac_row4_col3 {
#   background-color: #ebf3f8;
#   color: #000000;
# }
# #T_b32ac_row5_col1 {
#   background-color: #b4cce2;
#   color: #000000;
# }
# #T_b32ac_row5_col5 {
#   background-color: #f1f8fb;
#   color: #000000;
# }
# #T_b32ac_row5_col6 {
#   background-color: #d1e1ee;
#   color: #000000;
# }
# #T_b32ac_row6_col1 {
#   background-color: #8d99c8;
#   color: #f1f1f1;
# }
# #T_b32ac_row7_col6 {
#   background-color: #bcd1e5;
#   color: #000000;
# }
# #T_b32ac_row8_col1 {
#   background-color: #9bb6d7;
#   color: #000000;
# }
# #T_b32ac_row8_col6 {
#   background-color: #c0d4e6;
#   color: #000000;
# }
# #T_b32ac_row9_col1 {
#   background-color: #a3bfdc;
#   color: #000000;
# }
# #T_b32ac_row9_col6 {
#   background-color: #bacfe4;
#   color: #000000;
# }
# </style>
# <table id="T_b32ac">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target_drug</th>
#       <th id="T_b32ac_level0_col0" class="col_heading level0 col0" >Alcohol</th>
#       <th id="T_b32ac_level0_col1" class="col_heading level0 col1" >Cannabis</th>
#       <th id="T_b32ac_level0_col2" class="col_heading level0 col2" >Chocolate</th>
#       <th id="T_b32ac_level0_col3" class="col_heading level0 col3" >Caffeine</th>
#       <th id="T_b32ac_level0_col4" class="col_heading level0 col4" >Cocaine</th>
#       <th id="T_b32ac_level0_col5" class="col_heading level0 col5" >Mushrooms</th>
#       <th id="T_b32ac_level0_col6" class="col_heading level0 col6" >Nicotine</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b32ac_level0_row0" class="row_heading level0 row0" >dummy_train_error</th>
#       <td id="T_b32ac_row0_col0" class="data row0 col0" >0.038407</td>
#       <td id="T_b32ac_row0_col1" class="data row0 col1" >0.106412</td>
#       <td id="T_b32ac_row0_col2" class="data row0 col2" >0.024035</td>
#       <td id="T_b32ac_row0_col3" class="data row0 col3" >0.032453</td>
#       <td id="T_b32ac_row0_col4" class="data row0 col4" >0.074690</td>
#       <td id="T_b32ac_row0_col5" class="data row0 col5" >0.072768</td>
#       <td id="T_b32ac_row0_col6" class="data row0 col6" >0.120284</td>
#     </tr>
#     <tr>
#       <th id="T_b32ac_level0_row1" class="row_heading level0 row1" >dummy_test_error</th>
#       <td id="T_b32ac_row1_col0" class="data row1 col0" >0.040708</td>
#       <td id="T_b32ac_row1_col1" class="data row1 col1" >0.107995</td>
#       <td id="T_b32ac_row1_col2" class="data row1 col2" >0.026038</td>
#       <td id="T_b32ac_row1_col3" class="data row1 col3" >0.024089</td>
#       <td id="T_b32ac_row1_col4" class="data row1 col4" >0.072322</td>
#       <td id="T_b32ac_row1_col5" class="data row1 col5" >0.072051</td>
#       <td id="T_b32ac_row1_col6" class="data row1 col6" >0.117252</td>
#     </tr>
#     <tr>
#       <th id="T_b32ac_level0_row2" class="row_heading level0 row2" >ridge_train_error</th>
#       <td id="T_b32ac_row2_col0" class="data row2 col0" >0.034105</td>
#       <td id="T_b32ac_row2_col1" class="data row2 col1" >0.060842</td>
#       <td id="T_b32ac_row2_col2" class="data row2 col2" >0.023724</td>
#       <td id="T_b32ac_row2_col3" class="data row2 col3" >0.026593</td>
#       <td id="T_b32ac_row2_col4" class="data row2 col4" >0.039098</td>
#       <td id="T_b32ac_row2_col5" class="data row2 col5" >0.031610</td>
#       <td id="T_b32ac_row2_col6" class="data row2 col6" >0.097838</td>
#     </tr>
#     <tr>
#       <th id="T_b32ac_level0_row3" class="row_heading level0 row3" >ridge_test_error</th>
#       <td id="T_b32ac_row3_col0" class="data row3 col0" >0.037698</td>
#       <td id="T_b32ac_row3_col1" class="data row3 col1" >0.059446</td>
#       <td id="T_b32ac_row3_col2" class="data row3 col2" >0.025831</td>
#       <td id="T_b32ac_row3_col3" class="data row3 col3" >0.019697</td>
#       <td id="T_b32ac_row3_col4" class="data row3 col4" >0.038104</td>
#       <td id="T_b32ac_row3_col5" class="data row3 col5" >0.031011</td>
#       <td id="T_b32ac_row3_col6" class="data row3 col6" >0.095532</td>
#     </tr>
#     <tr>
#       <th id="T_b32ac_level0_row4" class="row_heading level0 row4" >nn_train_error</th>
#       <td id="T_b32ac_row4_col0" class="data row4 col0" >0.103095</td>
#       <td id="T_b32ac_row4_col1" class="data row4 col1" >0.073253</td>
#       <td id="T_b32ac_row4_col2" class="data row4 col2" >0.126404</td>
#       <td id="T_b32ac_row4_col3" class="data row4 col3" >0.150067</td>
#       <td id="T_b32ac_row4_col4" class="data row4 col4" >0.149931</td>
#       <td id="T_b32ac_row4_col5" class="data row4 col5" >0.142792</td>
#       <td id="T_b32ac_row4_col6" class="data row4 col6" >0.079503</td>
#     </tr>
#     <tr>
#       <th id="T_b32ac_level0_row5" class="row_heading level0 row5" >nn_test_error</th>
#       <td id="T_b32ac_row5_col0" class="data row5 col0" >0.121137</td>
#       <td id="T_b32ac_row5_col1" class="data row5 col1" >0.079613</td>
#       <td id="T_b32ac_row5_col2" class="data row5 col2" >0.136292</td>
#       <td id="T_b32ac_row5_col3" class="data row5 col3" >0.170755</td>
#       <td id="T_b32ac_row5_col4" class="data row5 col4" >0.149549</td>
#       <td id="T_b32ac_row5_col5" class="data row5 col5" >0.135740</td>
#       <td id="T_b32ac_row5_col6" class="data row5 col6" >0.105529</td>
#     </tr>
#     <tr>
#       <th id="T_b32ac_level0_row6" class="row_heading level0 row6" >svr_train_error</th>
#       <td id="T_b32ac_row6_col0" class="data row6 col0" >0.034778</td>
#       <td id="T_b32ac_row6_col1" class="data row6 col1" >0.060095</td>
#       <td id="T_b32ac_row6_col2" class="data row6 col2" >0.023718</td>
#       <td id="T_b32ac_row6_col3" class="data row6 col3" >0.027341</td>
#       <td id="T_b32ac_row6_col4" class="data row6 col4" >0.039286</td>
#       <td id="T_b32ac_row6_col5" class="data row6 col5" >0.030821</td>
#       <td id="T_b32ac_row6_col6" class="data row6 col6" >0.095057</td>
#     </tr>
#     <tr>
#       <th id="T_b32ac_level0_row7" class="row_heading level0 row7" >svr_test_error</th>
#       <td id="T_b32ac_row7_col0" class="data row7 col0" >0.037751</td>
#       <td id

# %% [markdown]
# # Training a model with the orginal numbers from the dataset.

# %%
data_path = "../data/raw"

#Load data mappings
mappings = json.load(open("data_mapping.json", "r"))


df = pd.read_csv(os.path.join(data_path, "drug_consumption.data"), names=mappings['column_headers'])
df = df.drop(columns=mappings['drop'])

X_train_raw, X_test_raw, y_train_raw, y_test_raw = train_test_split(df.drop(columns = mappings['drugs']),
                                     df[mappings['drugs']],
                                     test_size=0.2)

# %% [markdown]
# ## Dummy Classifier

# %%
dummy_results = {}
# Get the mean accuracy for each drug
for drug in mappings['drugs']: 
    dc_v2 = DummyClassifier(strategy="stratified")
    # dc_v2.fit(X_train_raw, y_train_raw[drug])
    dummy_results[drug] = pd.DataFrame(
                                cross_validate(dc_v2, 
                                               X_train_raw,
                                               y_train_raw[drug],
                                               cv = 5,
                                               return_train_score = True,
                                               scoring=scorers
                                )).mean().round(4)


raw_results = pd.DataFrame(dummy_results)

raw_results = raw_results.drop(index = ["fit_time", "score_time"]).T
raw_results = raw_results.reset_index()
raw_results = raw_results.rename(columns = {"index": "target_drug"})
raw_results = raw_results.set_index("target_drug").T

raw_results
# Out:
# /home/jenit/yes/envs/573/lib/python3.10/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /home/jenit/yes/envs/573/lib/python3.10/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# target_drug            Alcohol  Cannabis  Chocolate  Caffeine  Cocaine  \
# test_f1_score           0.2752    0.1691     0.3468    0.5557   0.3793
# train_f1_score          0.2681    0.1751     0.3471    0.5638   0.3621
# test_precision_score    0.2752    0.1691     0.3468    0.5557   0.3793
# train_precision_score   0.2681    0.1751     0.3471    0.5638   0.3621
# test_recall_score       0.2752    0.1691     0.3468    0.5557   0.3793
# train_recall_score      0.2681    0.1751     0.3471    0.5638   0.3621
#
# target_drug            Mushrooms  Nicotine
# test_f1_score             0.3402    0.2109
# train_f1_score            0.3394    0.2024
# test_precision_score      0.3402    0.2109
# train_precision_score     0.3394    0.2024
# test_recall_score         0.3402    0.2109
# train_recall_score        0.3394    0.2024

# %% [markdown]
# ## SVC Classifier

# %%
#column transformer
#Not using "drop" here as we dropped the columns after importing the dataset
preprocessor_v2 =  make_column_transformer(
        (StandardScaler(), mappings['numerical'] + mappings['ordinal']),
        (OneHotEncoder(drop='if_binary', dtype=int, handle_unknown='ignore'), mappings['categorical'])
    )

svc_pipe_v2 =  make_pipeline(
    preprocessor_v2, 
    SVC()
)

param_dist = {
    "svc__class_weight": ["balanced", None],
    "svc__gamma": 10.0 ** np.arange(-4, 4),
    "svc__C": 10.0 ** np.arange(-4, 4)
}

# Save the best model and score for each drug
raw_svc_best_estimator = {}
raw_svc_best_score_by_drug = {}

for drug in mappings['drugs']: 
    random_search = RandomizedSearchCV(svc_pipe_v2, 
                                       param_distributions = param_dist,
                                       n_jobs = -1,
                                       n_iter = 10,
                                       cv = 3, 
                                       return_train_score = True,
                                       random_state = 522,
                                       scoring=scorers,
                                       refit='f1_score'
                    )
    random_search.fit(X_train_raw, y_train_raw[drug])
    raw_svc_best_estimator[drug] = random_search.best_estimator_
    raw_svc_best_score_by_drug[drug] = [round(random_search.cv_results_['mean_train_f1_score'].mean(), 4), 
                                    round(random_search.cv_results_['mean_test_f1_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_train_recall_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_test_recall_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_train_precision_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_test_precision_score'].mean(), 4)
                                    ]
    
svc_results = pd.DataFrame(raw_svc_best_score_by_drug).T
svc_results = svc_results.reset_index()
svc_results = svc_results.rename(columns = {"index": "target_drug",
                                                0: "svc_train_f1_score",
                                                1: 'svc_test_f1_score',
                                                2: 'svc_train_recall_score',
                                                3: 'svc_test_recall_score',
                                                4: 'svc_train_precision_score',
                                                5: 'svc_test_precision_score'
                                }).set_index("target_drug").T

raw_results = pd.concat( [raw_results, svc_results] ,axis=0)
# Out:
# /home/jenit/yes/envs/573/lib/python3.10/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   warnings.warn(
# /home/jenit/yes/envs/573/lib/python3.10/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=3.
#   warnings.warn(

# %% [markdown]
# ## Decision Tree classifier

# %%
dt_pipe_v2 =  make_pipeline(
    preprocessor_v2, 
    DecisionTreeClassifier(random_state=522)
)

param_dist = {
    "decisiontreeclassifier__max_depth": [i for i in range(3, 20)],
}

# Save the best model and score for each drug
dt_best_estimator = {}
dt_best_score_by_drug = {}

for drug in mappings['drugs']: 
    random_search = GridSearchCV(dt_pipe_v2, 
                                    param_grid=param_dist,
                                       n_jobs = -1,
                                       cv = 5, 
                                       return_train_score = True,
                                       scoring=scorers,
                                       refit='f1_score'
                    )
    random_search.fit(X_train_raw, y_train_raw[drug])
    dt_best_estimator[drug] = random_search.best_estimator_
    dt_best_score_by_drug[drug] = [round(random_search.cv_results_['mean_train_f1_score'].mean(), 4), 
                                    round(random_search.cv_results_['mean_test_f1_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_train_recall_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_test_recall_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_train_precision_score'].mean(), 4),
                                    round(random_search.cv_results_['mean_test_precision_score'].mean(), 4)
                                ]
    
dt_score_by_drug = pd.DataFrame(dt_best_score_by_drug).T
dt_score_by_drug = dt_score_by_drug.reset_index()
dt_score_by_drug = dt_score_by_drug.rename(columns = {"index": "target_drug",
                                                0: "dt_train_f1_score",
                                                1: 'dt_test_f1_score',
                                                2: 'dt_train_recall_score',
                                                3: 'dt_test_recall_score',
                                                4: 'dt_train_precision_score',
                                                5: 'dt_test_precision_score'
                                }).set_index("target_drug").T

raw_results = pd.concat( [raw_results, dt_score_by_drug] ,axis=0)
# Out:
# /home/jenit/yes/envs/573/lib/python3.10/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /home/jenit/yes/envs/573/lib/python3.10/site-packages/sklearn/model_selection/_split.py:684: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(

# %% [markdown]
# ## NN classification

# %%
from sklearn.neural_network import MLPClassifier

#Creation of NN pipeline
nn_pipe =  make_pipeline(
    preprocessor_v2, 
    MLPClassifier((32,32,16),
                 learning_rate="invscaling",
                 random_state=522,
                 max_iter=5000,
                 batch_size=16,
    )
)

# Save the best model and score for each drug
nn_best_estimator = {}
nn_best_score_by_drug = {}

for drug in mappings['drugs']: 
    nn_pipe.fit(X_train_raw, y_train_raw[drug])
    
    nn_best_estimator[drug] = nn_pipe
    nn_best_score_by_drug[drug] = [round(f1_score(y_train_raw[drug], nn_pipe.predict(X_train_raw), average='weighted'), 4), 
                                    round(f1_score(y_test_raw[drug], nn_pipe.predict(X_test_raw), average='weighted'), 4),
                                    round(recall_score(y_train_raw[drug], nn_pipe.predict(X_train_raw), average='weighted'), 4),
                                    round(recall_score(y_test_raw[drug], nn_pipe.predict(X_test_raw), average='weighted'), 4),
                                    round(precision_score(y_train_raw[drug], nn_pipe.predict(X_train_raw), average='weighted', ), 4),
                                    round(precision_score(y_test_raw[drug], nn_pipe.predict(X_test_raw), average='weighted'), 4)
                                ]
    
score_by_nn = pd.DataFrame(nn_best_score_by_drug).T
score_by_nn = score_by_nn.reset_index()
score_by_nn = score_by_nn.rename(columns ={"index": "target_drug",
                                                0: "nn_train_f1_score",
                                                1: 'nn_test_f1_score',
                                                2: 'nn_train_recall_score',
                                                3: 'nn_test_recall_score',
                                                4: 'nn_train_precision_score',
                                                5: 'nn_test_precision_score'
                                   }).set_index("target_drug").T

raw_results = pd.concat( [raw_results, score_by_nn] ,axis=0)
# Out:
# /home/jenit/yes/envs/573/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
raw_results.reset_index().style.background_gradient(cmap='BuPu', low=0, high=1)
# Out:
# <style type="text/css">
# #T_a0752_row0_col1, #T_a0752_row2_col1, #T_a0752_row4_col1 {
#   background-color: #f3f9fc;
#   color: #000000;
# }
# #T_a0752_row0_col2, #T_a0752_row0_col6, #T_a0752_row1_col5, #T_a0752_row1_col6, #T_a0752_row1_col7, #T_a0752_row2_col2, #T_a0752_row2_col6, #T_a0752_row3_col5, #T_a0752_row3_col6, #T_a0752_row3_col7, #T_a0752_row4_col2, #T_a0752_row4_col6, #T_a0752_row5_col5, #T_a0752_row5_col6, #T_a0752_row5_col7, #T_a0752_row7_col3, #T_a0752_row7_col4, #T_a0752_row9_col3, #T_a0752_row9_col4, #T_a0752_row11_col3, #T_a0752_row11_col4, #T_a0752_row19_col3, #T_a0752_row21_col3, #T_a0752_row23_col3, #T_a0752_row25_col1, #T_a0752_row27_col3, #T_a0752_row29_col1 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_a0752_row0_col3, #T_a0752_row1_col3, #T_a0752_row2_col3, #T_a0752_row3_col3, #T_a0752_row4_col3, #T_a0752_row5_col3 {
#   background-color: #f3f9fb;
#   color: #000000;
# }
# #T_a0752_row0_col4, #T_a0752_row2_col4, #T_a0752_row4_col4, #T_a0752_row7_col7, #T_a0752_row9_col7, #T_a0752_row11_col7, #T_a0752_row19_col2, #T_a0752_row19_col6, #T_a0752_row21_col2, #T_a0752_row21_col6, #T_a0752_row23_col2, #T_a0752_row23_col6, #T_a0752_row25_col5, #T_a0752_row27_col2, #T_a0752_row27_col6, #T_a0752_row29_col5 {
#   background-color: #eef5f9;
#   color: #000000;
# }
# #T_a0752_row0_col5, #T_a0752_row2_col5, #T_a0752_row4_col5 {
#   background-color: #f5fafc;
#   color: #000000;
# }
# #T_a0752_row0_col7, #T_a0752_row1_col2, #T_a0752_row2_col7, #T_a0752_row3_col2, #T_a0752_row4_col7, #T_a0752_row5_col2, #T_a0752_row19_col1, #T_a0752_row21_col1, #T_a0752_row23_col1, #T_a0752_row25_col3, #T_a0752_row27_col1 {
#   background-color: #f6fbfd;
#   color: #000000;
# }
# #T_a0752_row1_col1, #T_a0752_row3_col1, #T_a0752_row5_col1 {
#   background-color: #f4fafc;
#   color: #000000;
# }
# #T_a0752_row1_col4, #T_a0752_row3_col4, #T_a0752_row5_col4, #T_a0752_row13_col1, #T_a0752_row15_col1, #T_a0752_row17_col1 {
#   background-color: #ecf4f9;
#   color: #000000;
# }
# #T_a0752_row6_col1, #T_a0752_row8_col1, #T_a0752_row10_col1 {
#   background-color: #d0e0ed;
#   color: #000000;
# }
# #T_a0752_row6_col2, #T_a0752_row8_col2, #T_a0752_row10_col2 {
#   background-color: #c5d8e9;
#   color: #000000;
# }
# #T_a0752_row6_col3, #T_a0752_row6_col5, #T_a0752_row8_col3, #T_a0752_row8_col5, #T_a0752_row10_col3, #T_a0752_row10_col5 {
#   background-color: #dae7f1;
#   color: #000000;
# }
# #T_a0752_row6_col4, #T_a0752_row8_col4, #T_a0752_row10_col4, #T_a0752_row13_col6, #T_a0752_row15_col6, #T_a0752_row17_col6 {
#   background-color: #e6f0f6;
#   color: #000000;
# }
# #T_a0752_row6_col6, #T_a0752_row8_col6, #T_a0752_row10_col6 {
#   background-color: #d7e5f0;
#   color: #000000;
# }
# #T_a0752_row6_col7, #T_a0752_row8_col7, #T_a0752_row10_col7 {
#   background-color: #c9dbea;
#   color: #000000;
# }
# #T_a0752_row7_col1, #T_a0752_row9_col1, #T_a0752_row11_col1, #T_a0752_row29_col6 {
#   background-color: #f0f7fa;
#   color: #000000;
# }
# #T_a0752_row7_col2, #T_a0752_row9_col2, #T_a0752_row11_col2, #T_a0752_row19_col5, #T_a0752_row19_col7, #T_a0752_row21_col5, #T_a0752_row21_col7, #T_a0752_row23_col5, #T_a0752_row23_col7, #T_a0752_row25_col7, #T_a0752_row27_col5, #T_a0752_row27_col7 {
#   background-color: #edf5f9;
#   color: #000000;
# }
# #T_a0752_row7_col5, #T_a0752_row9_col5, #T_a0752_row11_col5 {
#   background-color: #f2f8fb;
#   color: #000000;
# }
# #T_a0752_row7_col6, #T_a0752_row9_col6, #T_a0752_row11_col6, #T_a0752_row13_col3, #T_a0752_row15_col3, #T_a0752_row17_col3, #T_a0752_row25_col6, #T_a0752_row29_col2 {
#   background-color: #eff6fa;
#   color: #000000;
# }
# #T_a0752_row12_col1, #T_a0752_row14_col1, #T_a0752_row16_col1 {
#   background-color: #9bb6d7;
#   color: #000000;
# }
# #T_a0752_row12_col2, #T_a0752_row14_col2, #T_a0752_row16_col2 {
#   background-color: #9ab3d5;
#   color: #000000;
# }
# #T_a0752_row12_col3, #T_a0752_row14_col3, #T_a0752_row16_col3 {
#   background-color: #a4c0dc;
#   color: #000000;
# }
# #T_a0752_row12_col4, #T_a0752_row12_col6, #T_a0752_row14_col4, #T_a0752_row14_col6, #T_a0752_row16_col4, #T_a0752_row16_col6 {
#   background-color: #9dbad9;
#   color: #000000;
# }
# #T_a0752_row12_col5, #T_a0752_row14_col5, #T_a0752_row16_col5 {
#   background-color: #9cb8d8;
#   color: #000000;
# }
# #T_a0752_row12_col7, #T_a0752_row14_col7, #T_a0752_row16_col7 {
#   background-color: #99b1d4;
#   color: #000000;
# }
# #T_a0752_row13_col2, #T_a0752_row15_col2, #T_a0752_row17_col2 {
#   background-color: #e6f0f7;
#   color: #000000;
# }
# #T_a0752_row13_col4, #T_a0752_row15_col4, #T_a0752_row17_col4 {
#   background-color: #e1ecf4;
#   color: #000000;
# }
# #T_a0752_row13_col5, #T_a0752_row15_col5, #T_a0752_row17_col5, #T_a0752_row25_col4 {
#   background-color: #e8f1f7;
#   color: #000000;
# }
# #T_a0752_row13_col7, #T_a0752_row15_col7, #T_a0752_row17_col7, #T_a0752_row19_col4, #T_a0752_row21_col4, #T_a0752_row23_col4, #T_a0752_row27_col4 {
#   background-color: #eaf3f8;
#   color: #000000;
# }
# #T_a0752_row18_col1, #T_a0752_row18_col2, #T_a0752_row18_col3, #T_a0752_row18_col4, #T_a0752_row18_col5, #T_a0752_row18_col7, #T_a0752_row20_col1, #T_a0752_row20_col2, #T_a0752_row20_col3, #T_a0752_row20_col4, #T_a0752_row20_col5, #T_a0752_row20_col7, #T_a0752_row22_col1, #T_a0752_row22_col2, #T_a0752_row22_col3, #T_a0752_row22_col4, #T_a0752_row22_col5, #T_a0752_row22_col7, #T_a0752_row24_col1, #T_a0752_row24_col2, #T_a0752_row24_col3, #T_a0752_row24_col4, #T_a0752_row24_col5, #T_a0752_row24_col7, #T_a0752_row26_col1, #T_a0752_row26_col2, #T_a0752_row26_col3, #T_a0752_row26_col4, #T_a0752_row26_col5, #T_a0752_row26_col7, #T_a0752_row28_col3, #T_a0752_row28_col5 {
#   background-color: #8c97c6;
#   color: #f1f1f1;
# }
# #T_a0752_row18_col6, #T_a0752_row20_col6, #T_a0752_row22_col6, #T_a0752_row24_col6, #T_a0752_row26_col6, #T_a0752_row28_col1, #T_a0752_row28_col2, #T_a0752_row28_col4, #T_a0752_row28_col6, #T_a0752_row28_col7 {
#   background-color: #8c95c6;
#   color: #f1f1f1;
# }
# #T_a0752_row25_col2 {
#   background-color: #eef6fa;
#   color: #000000;
# }
# #T_a0752_row29_col3 {
#   background-color: #f6fbfc;
#   color: #000000;
# }
# #T_a0752_row29_col4 {
#   background-color: #e5eff6;
#   color: #000000;
# }
# #T_a0752_row29_col7 {
#   background-color: #ebf4f8;
#   color: #000000;
# }
# </style>
# <table id="T_a0752">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target_drug</th>
#       <th id="T_a0752_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_a0752_level0_col1" class="col_heading level0 col1" >Alcohol</th>
#       <th id="T_a0752_level0_col2" class="col_heading level0 col2" >Cannabis</th>
#       <th id="T_a0752_level0_col3" class="col_heading level0 col3" >Chocolate</th>
#       <th id="T_a0752_level0_col4" class="col_heading level0 col4" >Caffeine</th>
#       <th id="T_a0752_level0_col5" class="col_heading level0 col5" >Cocaine</th>
#       <th id="T_a0752_level0_col6" class="col_heading level0 col6" >Mushrooms</th>
#       <th id="T_a0752_level0_col7" class="col_heading level0 col7" >Nicotine</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0752_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0752_row0_col0" class="data row0 col0" >test_f1_score</td>
#       <td id="T_a0752_row0_col1" class="data row0 col1" >0.275200</td>
#       <td id="T_a0752_row0_col2" class="data row0 col2" >0.169100</td>
#       <td id="T_a0752_row0_col3" class="data row0 col3" >0.346800</td>
#       <td id="T_a0752_row0_col4" class="data row0 col4" >0.555700</td>
#       <td id="T_a0752_row0_col5" class="data row0 col5" >0.379300</td>
#       <td id="T_a0752_row0_col6" class="data row0 col6" >0.340200</td>
#       <td id="T_a0752_row0_col7" class="data row0 col7" >0.210900</td>
#     </tr>
#     <tr>
#       <th id="T_a0752_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a0752_row1_col0" class="data row1 col0" >train_f1_score</td>
#       <td id="T_a0752_row1_col1" class="data row1 col1" >0.268100</td>
#       <td id="T_a0752_row1_col2" class="data row1 col2" >0.175100</td>
#       <td id="T_a0752_row1_col3" class="data row1 col3" >0.347100</td>
#       <td id="T_a0752_row1_col4" class="data row1 col4" >0.563800</td>
#       <td id="T_a0752_row1_col5" clas

# %%
x_enc = preprocessor_v2.fit_transform(X_train_raw)
pd.DataFrame(x_enc, columns=preprocessor_v2.get_feature_names_out()).corr().style.background_gradient(cmap = "BrBG")
# Out:
# <style type="text/css">
# #T_7d9d1_row0_col0, #T_7d9d1_row1_col1, #T_7d9d1_row2_col2, #T_7d9d1_row3_col3, #T_7d9d1_row4_col4, #T_7d9d1_row5_col5, #T_7d9d1_row6_col6, #T_7d9d1_row7_col7, #T_7d9d1_row8_col8, #T_7d9d1_row9_col9 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_7d9d1_row0_col1, #T_7d9d1_row0_col4, #T_7d9d1_row1_col0, #T_7d9d1_row4_col7, #T_7d9d1_row5_col2, #T_7d9d1_row5_col8, #T_7d9d1_row7_col3, #T_7d9d1_row7_col6, #T_7d9d1_row8_col5, #T_7d9d1_row8_col9 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_7d9d1_row0_col2 {
#   background-color: #b57826;
#   color: #f1f1f1;
# }
# #T_7d9d1_row0_col3 {
#   background-color: #5b3406;
#   color: #f1f1f1;
# }
# #T_7d9d1_row0_col5, #T_7d9d1_row3_col0 {
#   background-color: #ad7021;
#   color: #f1f1f1;
# }
# #T_7d9d1_row0_col6, #T_7d9d1_row7_col4 {
#   background-color: #683c07;
#   color: #f1f1f1;
# }
# #T_7d9d1_row0_col7, #T_7d9d1_row4_col5, #T_7d9d1_row6_col9, #T_7d9d1_row9_col3 {
#   background-color: #efdcad;
#   color: #000000;
# }
# #T_7d9d1_row0_col8, #T_7d9d1_row1_col3 {
#   background-color: #dec17b;
#   color: #000000;
# }
# #T_7d9d1_row0_col9 {
#   background-color: #cd9d50;
#   color: #f1f1f1;
# }
# #T_7d9d1_row1_col2 {
#   background-color: #f1e1b5;
#   color: #000000;
# }
# #T_7d9d1_row1_col4 {
#   background-color: #f5f4f2;
#   color: #000000;
# }
# #T_7d9d1_row1_col5, #T_7d9d1_row3_col6 {
#   background-color: #c28633;
#   color: #f1f1f1;
# }
# #T_7d9d1_row1_col6 {
#   background-color: #c38936;
#   color: #f1f1f1;
# }
# #T_7d9d1_row1_col7, #T_7d9d1_row4_col9 {
#   background-color: #e7cf94;
#   color: #000000;
# }
# #T_7d9d1_row1_col8 {
#   background-color: #f6e8c3;
#   color: #000000;
# }
# #T_7d9d1_row1_col9 {
#   background-color: #c99546;
#   color: #f1f1f1;
# }
# #T_7d9d1_row2_col0 {
#   background-color: #e0c481;
#   color: #000000;
# }
# #T_7d9d1_row2_col1 {
#   background-color: #f5f2e8;
#   color: #000000;
# }
# #T_7d9d1_row2_col3, #T_7d9d1_row3_col2 {
#   background-color: #bd7f2c;
#   color: #f1f1f1;
# }
# #T_7d9d1_row2_col4, #T_7d9d1_row6_col2 {
#   background-color: #c79040;
#   color: #f1f1f1;
# }
# #T_7d9d1_row2_col5, #T_7d9d1_row3_col7 {
#   background-color: #804a09;
#   color: #f1f1f1;
# }
# #T_7d9d1_row2_col6 {
#   background-color: #b17423;
#   color: #f1f1f1;
# }
# #T_7d9d1_row2_col7 {
#   background-color: #f5f0e2;
#   color: #000000;
# }
# #T_7d9d1_row2_col8 {
#   background-color: #d5edea;
#   color: #000000;
# }
# #T_7d9d1_row2_col9 {
#   background-color: #894f0a;
#   color: #f1f1f1;
# }
# #T_7d9d1_row3_col1 {
#   background-color: #f6e9c7;
#   color: #000000;
# }
# #T_7d9d1_row3_col4 {
#   background-color: #f6edd5;
#   color: #000000;
# }
# #T_7d9d1_row3_col5 {
#   background-color: #ddbe78;
#   color: #000000;
# }
# #T_7d9d1_row3_col8, #T_7d9d1_row9_col2 {
#   background-color: #824b09;
#   color: #f1f1f1;
# }
# #T_7d9d1_row3_col9 {
#   background-color: #f0deb0;
#   color: #000000;
# }
# #T_7d9d1_row4_col0 {
#   background-color: #6a3d07;
#   color: #f1f1f1;
# }
# #T_7d9d1_row4_col1 {
#   background-color: #eff3f3;
#   color: #000000;
# }
# #T_7d9d1_row4_col2 {
#   background-color: #975b12;
#   color: #f1f1f1;
# }
# #T_7d9d1_row4_col3 {
#   background-color: #edd9a8;
#   color: #000000;
# }
# #T_7d9d1_row4_col6 {
#   background-color: #e4ca8c;
#   color: #000000;
# }
# #T_7d9d1_row4_col8 {
#   background-color: #844c09;
#   color: #f1f1f1;
# }
# #T_7d9d1_row5_col0 {
#   background-color: #c89343;
#   color: #f1f1f1;
# }
# #T_7d9d1_row5_col1, #T_7d9d1_row5_col9 {
#   background-color: #d6af65;
#   color: #000000;
# }
# #T_7d9d1_row5_col3, #T_7d9d1_row6_col0 {
#   background-color: #ca9849;
#   color: #f1f1f1;
# }
# #T_7d9d1_row5_col4 {
#   background-color: #f4e5be;
#   color: #000000;
# }
# #T_7d9d1_row5_col6 {
#   background-color: #cea053;
#   color: #f1f1f1;
# }
# #T_7d9d1_row5_col7, #T_7d9d1_row7_col5, #T_7d9d1_row8_col4 {
#   background-color: #955910;
#   color: #f1f1f1;
# }
# #T_7d9d1_row6_col1 {
#   background-color: #f1dfb3;
#   color: #000000;
# }
# #T_7d9d1_row6_col3 {
#   background-color: #d2a75c;
#   color: #000000;
# }
# #T_7d9d1_row6_col4 {
#   background-color: #f6edd7;
#   color: #000000;
# }
# #T_7d9d1_row6_col5, #T_7d9d1_row8_col0, #T_7d9d1_row9_col0 {
#   background-color: #ebd6a2;
#   color: #000000;
# }
# #T_7d9d1_row6_col7 {
#   background-color: #a16518;
#   color: #f1f1f1;
# }
# #T_7d9d1_row6_col8 {
#   background-color: #a3671a;
#   color: #f1f1f1;
# }
# #T_7d9d1_row7_col0 {
#   background-color: #f6eacb;
#   color: #000000;
# }
# #T_7d9d1_row7_col1 {
#   background-color: #f2e2b8;
#   color: #000000;
# }
# #T_7d9d1_row7_col2 {
#   background-color: #f6eac9;
#   color: #000000;
# }
# #T_7d9d1_row7_col8, #T_7d9d1_row8_col7 {
#   background-color: #76c6ba;
#   color: #000000;
# }
# #T_7d9d1_row7_col9 {
#   background-color: #734208;
#   color: #f1f1f1;
# }
# #T_7d9d1_row8_col1 {
#   background-color: #f6eedb;
#   color: #000000;
# }
# #T_7d9d1_row8_col2 {
#   background-color: #e7f2f0;
#   color: #000000;
# }
# #T_7d9d1_row8_col3 {
#   background-color: #563105;
#   color: #f1f1f1;
# }
# #T_7d9d1_row8_col6 {
#   background-color: #583305;
#   color: #f1f1f1;
# }
# #T_7d9d1_row9_col1 {
#   background-color: #e9d39d;
#   color: #000000;
# }
# #T_7d9d1_row9_col4 {
#   background-color: #f6e9c5;
#   color: #000000;
# }
# #T_7d9d1_row9_col5 {
#   background-color: #e5cc8f;
#   color: #000000;
# }
# #T_7d9d1_row9_col6 {
#   background-color: #e3c989;
#   color: #000000;
# }
# #T_7d9d1_row9_col7 {
#   background-color: #995d13;
#   color: #f1f1f1;
# }
# #T_7d9d1_row9_col8 {
#   background-color: #7c4709;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7d9d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d9d1_level0_col0" class="col_heading level0 col0" >standardscaler__Neuroticism</th>
#       <th id="T_7d9d1_level0_col1" class="col_heading level0 col1" >standardscaler__Extraversion</th>
#       <th id="T_7d9d1_level0_col2" class="col_heading level0 col2" >standardscaler__Openness</th>
#       <th id="T_7d9d1_level0_col3" class="col_heading level0 col3" >standardscaler__Agreeableness</th>
#       <th id="T_7d9d1_level0_col4" class="col_heading level0 col4" >standardscaler__Conscientiousness</th>
#       <th id="T_7d9d1_level0_col5" class="col_heading level0 col5" >standardscaler__Age</th>
#       <th id="T_7d9d1_level0_col6" class="col_heading level0 col6" >standardscaler__Education</th>
#       <th id="T_7d9d1_level0_col7" class="col_heading level0 col7" >standardscaler__Impulsiveness</th>
#       <th id="T_7d9d1_level0_col8" class="col_heading level0 col8" >standardscaler__SensationSeeking</th>
#       <th id="T_7d9d1_level0_col9" class="col_heading level0 col9" >onehotencoder__Gender_0.48246</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d9d1_level0_row0" class="row_heading level0 row0" >standardscaler__Neuroticism</th>
#       <td id="T_7d9d1_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_7d9d1_row0_col1" class="data row0 col1" >-0.441351</td>
#       <td id="T_7d9d1_row0_col2" class="data row0 col2" >0.002069</td>
#       <td id="T_7d9d1_row0_col3" class="data row0 col3" >-0.204002</td>
#       <td id="T_7d9d1_row0_col4" class="data row0 col4" >-0.380731</td>
#       <td id="T_7d9d1_row0_col5" class="data row0 col5" >-0.109714</td>
#       <td id="T_7d9d1_row0_col6" class="data row0 col6" >-0.098402</td>
#       <td id="T_7d9d1_row0_col7" class="data row0 col7" >0.160635</td>
#       <td id="T_7d9d1_row0_col8" class="data row0 col8" >0.066570</td>
#       <td id="T_7d9d1_row0_col9" class="data row0 col9" >0.069124</td>
#     </tr>
#     <tr>
#       <th id="T_7d9d1_level0_row1" class="row_heading level0 row1" >standardscaler__Extraversion</th>
#       <td id="T_7d9d1_row1_col0" class="data row1 col0" >-0.441351</td>
#       <td id="T_7d9d1_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_7d9d1_row1_col2" class="data row1 col2" >0.245108</td>
#       <td id="T_7d9d1_row1_col3" class="data row1 col3" >0.145109</td>
#       <td id="T_7d9d1_row1_col4" class="data row1 col4" >0.299102</td>
#       <td id="T_7d9d1_row1_col5" class="data row1 col5" >-0.051831</td>
#       <td id="T_7d9d1_row1_col6" class="data row1 col6" >0.102547</td>
#       <td id="T_7d9d1_row1_col7" class="data row1 col7" >0.111876</td>
#       <td id="T_7d9d1_row1_col8" class="data row1 col8" >0.205145</td>
#       <td id="T_7d9d1_row1_col9" class="data row1 col9" >0.057626</td>
#     </tr>
#     <tr>
#       <th

# %% [markdown]
# ## KNN classification
